# %% [markdown]
# ## tasks
#
# Part 1.1
# 1. Create repository with 3 files:
# Readme , 1.txt (with text “this is file 1.txt”) , 2.txt (with text “this is file 2.txt”)
# 2. Clone to local
# 3. Add file 3.txt ( with text “this is file 3.txt”) and save changes (commit)
# 4. Add tag v0.0.1
# 5. Add tag v0.0.0 to initial commit
# 6. Update tag v0.0.0 to remote repo (GitHub)
# 7. On remote repo :
# Create file 4.txt (with text “this is file 4.txt”)
# 8. From local update all changes to remote repo ( push ) and check that all tags from local are exist on remote repo
# 9. On local: change file 1.txt ( change text to “this is new text in file 1.txt”)
# 10. On local: change file 2.txt ( add text “one more line from local ”)
# 11. On remote repo : change file 2.txt ( add text “one more line from Remote Repo”)
# 12. On local: Save changes (commit)
# 13. Push to remote repo

# %% [markdown]
# ## answer
#
# PART 1.1
#
# 1. created the 3 files on GitHub
# 2. git clone https://github.com/UwebDevCom/Test-RTC.git
# 3. git add . , git commit -m "new file was added"
# 4. git tag v0.0.1
# 5. git tag v0.0.0 4d5c21e
# 6. git push origin tag v0.0.0
# 7. created the 4 on GitHub
# 8. git pull, git push origin main
# 9. text changed on file 1
# 10.text changed on file 2
# 11. created the 2 on GitHub
# 12. git commit -am "new changes on files 1,2"
# 13. git pull , fix conflicts, git add ., git commit -m "fixed conflicts", git push
#
# PART 1.2
# At work, i use git stash in couple of usescases:
#  - while i want to move to another branch and i want to keep my changes aside. i use "git stash"
#  - also i use "git stash pop" to get back to the last stash
#  - also use the stach to go back to the last commit
